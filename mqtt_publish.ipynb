# %% [markdown]
# <a href="https://colab.research.google.com/github/ekyuho/Physical-Computing/blob/main/mqtt_publish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.publish as publish

# %%
publish.single("ewha/iot/2025", "mqtt 재미있다~~  !!", hostname="test.mosquitto.org")
